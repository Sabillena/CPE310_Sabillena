# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabillena/CPE310_Sabillena/blob/main/CPE310_Hands_on_Activity_6_2_Getting_Started_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXERCISES

# %% [markdown]
# 1.1 Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
import pandas as pd

yellowtaxi = pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data.csv', nrows = 5)
yellowtaxi
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5      1      0.5
# ...

# %% [markdown]
# 1.2 Find the dimensions (number of rows and number of columns) in the data.

# %%
yellowtaxi.shape
# Out:
# (5, 18)

# %% [markdown]
# 1.3 Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
yellowtaxi.describe()[['fare_amount','tip_amount','tolls_amount','total_amount']]
# Out:
#        fare_amount  tip_amount  tolls_amount  total_amount
# count     5.000000    5.000000      5.000000       5.00000
# mean     14.600000    2.960000      1.224000      22.58400
# std       8.429116    3.270505      2.736947      14.54879
# min       9.500000    0.000000      0.000000      12.30000
# 25%      10.500000    0.500000      0.000000      15.30000
# 50%      10.500000    2.000000      0.000000      15.80000
# 75%      13.000000    4.320000      0.000000      21.62000
# max      29.500000    7.980000      6.120000      47.90000

# %% [markdown]
# 1.4 Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
longest_trip = yellowtaxi.loc[yellowtaxi['trip_distance'].idxmax(), ['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']]

longest_trip
# Out:
# fare_amount     29.5
# tip_amount      7.98
# tolls_amount    6.12
# total_amount    47.9
# Name: 0, dtype: object
